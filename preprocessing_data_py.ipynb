# %% [markdown]
# <a href="https://colab.research.google.com/github/DINESH8675/Airbnb-Analysis/blob/main/preprocessing_data_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
import pandas as pd
import pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.4.2)

# %%
client= pymongo.MongoClient("mongodb+srv://r_dineshkumar:rdineshkumar@cluster0.e1g0htd.mongodb.net/?retryWrites=true&w=majority")
db = client['sample_airbnb']
col = db['listingsAndReviews']

# %%
data = []
for i in col.find( {}, {'_id':1,'listing_url':1,'name':1,'property_type':1,'room_type':1,'bed_type':1,
                        'minimum_nights':1,'maximum_nights':1,'cancellation_policy':1,'accommodates':1,
                        'bedrooms':1,'beds':1,'number_of_reviews':1,'bathrooms':1,'price':1,
                        'cleaning_fee':1,'extra_people':1,'guests_included':1,'images.picture_url':1,
                        'review_scores.review_scores_rating':1} ):
    data.append(i)

df_1 = pd.DataFrame(data)
df_1['images'] = df_1['images'].apply(lambda x: x['picture_url'])
df_1['review_scores'] = df_1['review_scores'].apply(lambda x: x.get('review_scores_rating',0))
df_1.head()
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10047964  https://www.airbnb.com/rooms/10047964
# 2  10057447  https://www.airbnb.com/rooms/10057447
# 3  10083468  https://www.airbnb.com/rooms/10083468
# 4  10096773  https://www.airbnb.com/rooms/10096773
#
#                              name property_type        room_type  bed_type  \
# 0         Ribeira Charming Duplex         House  Entire home/apt  Real Bed
# 1  Charming Flat in Downtown Moda         House  Entire home/apt  Real Bed
# 2  Modern Spacious 1 Bedroom Loft     Apartment  Entire home/apt  Real Bed
# 3               Be Happy in Porto          Loft  Entire home/apt  Real Bed
# 4       Easy 1 Bedroom in Chelsea     Apartment  Entire home/apt  Real Bed
#
#   minimum_nights maximum_nights cancellation_policy  accommodates  bedrooms  \
# 0              2             30            moderate             8       3.0
# 1              2           1125            flexible             6       2.0
# 2              1           1125            flexible             4       1.0
# 3              2           1125            moderate             2       1.0
# 4              2           1125            flexible             2       1.0
#
#    beds  number_of_reviews bathrooms   price cleaning_fee extra_people  \
# 0   5.0                 51       1.0   80.00        35.00        15.00
# 1   6.0                  1       1.0  527.00       211.00       211.00
# 2   2.0                  0       1.0   50.00          NaN        31.00
# 3   1.0                178       1.0   30.00        10.00         0.00
# 4   1.0                  1       1.0  145.00        60.00         0.00
#
#   guests_included                                             images  \
# 0               6  https://a0.muscache.com/im/pictures/e83e702f-e...
# 1               1  https://a0.muscache.com/im/pictures/231120b6-e...
# 2               1  https://a0.muscache.com/im/pictures/9fa69ad8-c...
# 3               1  https://a0.muscache.com/im/pictures/9420dabf-6...
# 4               1  https://a0.muscache.com/im/pictures/ceb6e8b2-d...
#
#    review_scores
# 0             89
# 1            100
# 2              0
# 3             97
# 4            100

# %%
total=df_1["number_of_reviews"].sum()
total
# Out:
# 153354

# %%
df_1["review_scores"].sum()
# Out:
# 379938

# %%
df_1.isnull().sum()
# Out:
# _id                       0
# listing_url               0
# name                      0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# cleaning_fee           1531
# extra_people              0
# guests_included           0
# images                    0
# review_scores             0
# dtype: int64

# %%
df_1['bedrooms'].fillna(0, inplace=True)
df_1['beds'].fillna(0, inplace=True)
df_1['bathrooms'].fillna(0, inplace=True)
df_1['cleaning_fee'].fillna('Not Specified', inplace=True)
df_1.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# dtype: int64

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  5555 non-null   object
#  1   listing_url          5555 non-null   object
#  2   name                 5555 non-null   object
#  3   property_type        5555 non-null   object
#  4   room_type            5555 non-null   object
#  5   bed_type             5555 non-null   object
#  6   minimum_nights       5555 non-null   object
#  7   maximum_nights       5555 non-null   object
#  8   cancellation_policy  5555 non-null   object
#  9   accommodates         5555 non-null   int64
#  10  bedrooms             5555 non-null   float64
#  11  beds                 5555 non-null   float64
#  12  number_of_reviews    5555 non-null   int64
#  13  bathrooms            5555 non-null   object
#  14  price                5555 non-null   object
#  15  cleaning_fee         5555 non-null   object
#  16  extra_people         5555 non-null   object
#  17  guests_included      5555 non-null   object
#  18  images               5555 non-null   object
#  19  review_scores        5555 non-null   int64
# dtypes: float64(2), int64(3), object(15)
# memory usage: 868.1+ KB

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# price                   object
# cleaning_fee            object
# extra_people            object
# guests_included         object
# images                  object
# review_scores            int64
# dtype: object

# %%
df_1['minimum_nights'] = df_1['minimum_nights'].astype(int)
df_1['maximum_nights'] = df_1['maximum_nights'].astype(int)
df_1['bedrooms'] = df_1['bedrooms'].astype(int)
df_1['beds'] = df_1['beds'].astype(int)
df_1['bathrooms'] = df_1['bathrooms'].astype(str).astype(float)
df_1['price'] = df_1['price'].astype(str).astype(float).astype(int)
df_1['cleaning_fee'] = df_1['cleaning_fee'].apply(lambda x: int(float(str(x))) if x != 'Not Specified' else 'Not Specified')
df_1['extra_people'] = df_1['extra_people'].astype(str).astype(float).astype(int)
df_1['guests_included'] = df_1['guests_included'].astype(str).astype(int)

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights           int64
# maximum_nights           int64
# cancellation_policy     object
# accommodates             int64
# bedrooms                 int64
# beds                     int64
# number_of_reviews        int64
# bathrooms              float64
# price                    int64
# cleaning_fee            object
# extra_people             int64
# guests_included          int64
# images                  object
# review_scores            int64
# dtype: object

# %%
df_1.describe().T
# Out:
#                     count          mean           std  min   25%     50%  \
# minimum_nights     5555.0  5.564356e+00  2.261386e+01  1.0   1.0     2.0
# maximum_nights     5555.0  1.382776e+06  5.256920e+07  1.0  59.0  1125.0
# accommodates       5555.0  3.505851e+00  2.297019e+00  1.0   2.0     3.0
# bedrooms           5555.0  1.410441e+00  1.042334e+00  0.0   1.0     1.0
# beds               5555.0  2.066607e+00  1.620858e+00  0.0   1.0     2.0
# number_of_reviews  5555.0  2.760648e+01  4.979838e+01  0.0   1.0     5.0
# bathrooms          5555.0  1.288839e+00  7.037643e-01  0.0   1.0     1.0
# price              5555.0  2.787662e+02  8.422155e+02  9.0  70.0   129.0
# extra_people       5555.0  2.279190e+01  6.933151e+01  0.0   0.0     0.0
# guests_included    5555.0  1.747435e+00  1.487352e+00  1.0   1.0     1.0
# review_scores      5555.0  6.839568e+01  4.182983e+01  0.0   0.0    92.0
#
#                       75%           max
# minimum_nights        3.0  1.250000e+03
# maximum_nights     1125.0  2.147484e+09
# accommodates          4.0  1.600000e+01
# bedrooms              2.0  2.000000e+01
# beds                  3.0  2.500000e+01
# number_of_reviews    32.0  5.330000e+02
# bathrooms             1.0  1.600000e+01
# price               280.0  4.884200e+04
# extra_people         20.0  2.346000e+03
# guests_included       2.0  1.600000e+01
# review_scores        98.0  1.000000e+02

# %%
df_1.head(5)
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10047964  https://www.airbnb.com/rooms/10047964
# 2  10057447  https://www.airbnb.com/rooms/10057447
# 3  10083468  https://www.airbnb.com/rooms/10083468
# 4  10096773  https://www.airbnb.com/rooms/10096773
#
#                              name property_type        room_type  bed_type  \
# 0         Ribeira Charming Duplex         House  Entire home/apt  Real Bed
# 1  Charming Flat in Downtown Moda         House  Entire home/apt  Real Bed
# 2  Modern Spacious 1 Bedroom Loft     Apartment  Entire home/apt  Real Bed
# 3               Be Happy in Porto          Loft  Entire home/apt  Real Bed
# 4       Easy 1 Bedroom in Chelsea     Apartment  Entire home/apt  Real Bed
#
#    minimum_nights  maximum_nights cancellation_policy  accommodates  bedrooms  \
# 0               2              30            moderate             8         3
# 1               2            1125            flexible             6         2
# 2               1            1125            flexible             4         1
# 3               2            1125            moderate             2         1
# 4               2            1125            flexible             2         1
#
#    beds  number_of_reviews  bathrooms  price   cleaning_fee  extra_people  \
# 0     5                 51        1.0     80             35            15
# 1     6                  1        1.0    527            211           211
# 2     2                  0        1.0     50  Not Specified            31
# 3     1                178        1.0     30             10             0
# 4     1                  1        1.0    145             60             0
#
#    guests_included                                             images  \
# 0                6  https://a0.muscache.com/im/pictures/e83e702f-e...
# 1                1  https://a0.muscache.com/im/pictures/231120b6-e...
# 2                1  https://a0.muscache.com/im/pictures/9fa69ad8-c...
# 3                1  https://a0.muscache.com/im/pictures/9420dabf-6...
# 4                1  https://a0.muscache.com/im/pictures/ceb6e8b2-d...
#
#    review_scores
# 0             89
# 1            100
# 2              0
# 3             97
# 4            100

# %%
host = []
for i in col.find( {}, {'_id':1, 'host':1}):
    host.append(i)

df_host = pd.DataFrame(host)
host_keys = list(df_host.iloc[0,1].keys())
host_keys.remove('host_about')

for i in host_keys:
    if i == 'host_response_time':
        df_host['host_response_time'] = df_host['host'].apply(lambda x: x['host_response_time'] if 'host_response_time' in x else 'Not Specified')
    else:
        df_host[i] = df_host['host'].apply(lambda x: x[i] if i in x and x[i]!='' else 'Not Specified')

df_host.drop(columns=['host'], inplace=True)
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0  10006546  51399391  https://www.airbnb.com/users/show/51399391
# 1  10047964   1241644   https://www.airbnb.com/users/show/1241644
# 2  10057447  51612949  https://www.airbnb.com/users/show/51612949
# 3  10083468  27518920  https://www.airbnb.com/users/show/27518920
# 4  10096773  34607505  https://www.airbnb.com/users/show/34607505
#
#      host_name                          host_location host_response_time  \
# 0  Ana&Gonçalo        Porto, Porto District, Portugal     within an hour
# 1       Zeynep             Istanbul, Istanbul, Turkey      Not Specified
# 2   Konstantin               Montreal, Quebec, Canada      Not Specified
# 3        Fábio  São Félix da Marinha, Porto, Portugal     within an hour
# 4        Scott      New York, New York, United States      Not Specified
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...
# 1  https://a0.muscache.com/im/users/1241644/profi...
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 3  https://a0.muscache.com/im/pictures/user/30283...
# 4  https://a0.muscache.com/im/pictures/675cec89-7...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
# 1  https://a0.muscache.com/im/users/1241644/profi...               Moda
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 3  https://a0.muscache.com/im/pictures/user/30283...      Not Specified
# 4  https://a0.muscache.com/im/pictures/675cec89-7...            Chelsea
#
#   host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                100              False                  True
# 1      Not Specified              False                  True
# 2      Not Specified              False                  True
# 3                 90               True                  True
# 4      Not Specified              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    True                    3                          3
# 1                    True                    2                          2
# 2                   False                    1                          1
# 3                    True                    3                          3
# 4                    True                    1                          1
#
#                                   host_verifications
# 0  [email, phone, reviews, jumio, offline_governm...
# 1  [email, phone, facebook, reviews, jumio, gover...
# 2  [email, phone, jumio, offline_government_id, s...
# 3  [email, phone, reviews, manual_offline, jumio,...
# 4             [email, phone, facebook, reviews, kba]

# %%
df_host['host_is_superhost'] = df_host['host_is_superhost'].map({False:'No',True:'Yes'})
df_host['host_has_profile_pic'] = df_host['host_has_profile_pic'].map({False:'No',True:'Yes'})
df_host['host_identity_verified'] = df_host['host_identity_verified'].map({False:'No',True:'Yes'})
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0  10006546  51399391  https://www.airbnb.com/users/show/51399391
# 1  10047964   1241644   https://www.airbnb.com/users/show/1241644
# 2  10057447  51612949  https://www.airbnb.com/users/show/51612949
# 3  10083468  27518920  https://www.airbnb.com/users/show/27518920
# 4  10096773  34607505  https://www.airbnb.com/users/show/34607505
#
#      host_name                          host_location host_response_time  \
# 0  Ana&Gonçalo        Porto, Porto District, Portugal     within an hour
# 1       Zeynep             Istanbul, Istanbul, Turkey      Not Specified
# 2   Konstantin               Montreal, Quebec, Canada      Not Specified
# 3        Fábio  São Félix da Marinha, Porto, Portugal     within an hour
# 4        Scott      New York, New York, United States      Not Specified
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...
# 1  https://a0.muscache.com/im/users/1241644/profi...
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 3  https://a0.muscache.com/im/pictures/user/30283...
# 4  https://a0.muscache.com/im/pictures/675cec89-7...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
# 1  https://a0.muscache.com/im/users/1241644/profi...               Moda
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 3  https://a0.muscache.com/im/pictures/user/30283...      Not Specified
# 4  https://a0.muscache.com/im/pictures/675cec89-7...            Chelsea
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                100                No                  Yes
# 1      Not Specified                No                  Yes
# 2      Not Specified                No                  Yes
# 3                 90               Yes                  Yes
# 4      Not Specified                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    Yes                    3                          3
# 1                    Yes                    2                          2
# 2                     No                    1                          1
# 3                    Yes                    3                          3
# 4                    Yes                    1                          1
#
#                                   host_verifications
# 0  [email, phone, reviews, jumio, offline_governm...
# 1  [email, phone, facebook, reviews, jumio, gover...
# 2  [email, phone, jumio, offline_government_id, s...
# 3  [email, phone, reviews, manual_offline, jumio,...
# 4             [email, phone, facebook, reviews, kba]

# %%
df_host['host_name'].head(10)
# Out:
# 0    Ana&Gonçalo
# 1         Zeynep
# 2     Konstantin
# 3          Fábio
# 4          Scott
# 5          Ahmet
# 6          Ahmet
# 7        Chelsea
# 8           Lane
# 9           Josh
# Name: host_name, dtype: object

# %%
df_host.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
df_host.dtypes
# Out:
# _id                          object
# host_id                      object
# host_url                     object
# host_name                    object
# host_location                object
# host_response_time           object
# host_thumbnail_url           object
# host_picture_url             object
# host_neighbourhood           object
# host_response_rate           object
# host_is_superhost            object
# host_has_profile_pic         object
# host_identity_verified       object
# host_listings_count           int64
# host_total_listings_count     int64
# host_verifications           object
# dtype: object

# %%
address = []
for i in col.find( {}, {'_id':1, 'address':1}):
    address.append(i)

df_address = pd.DataFrame(address)
address_keys = list(df_address.iloc[0,1].keys())

for i in address_keys:
    if i == 'location':
        df_address['location_type'] = df_address['address'].apply(lambda x: x['location']['type'])
        df_address['longitude'] = df_address['address'].apply(lambda x: x['location']['coordinates'][0])
        df_address['latitude'] = df_address['address'].apply(lambda x: x['location']['coordinates'][1])
        df_address['is_location_exact'] = df_address['address'].apply(lambda x: x['location']['is_location_exact'])
    else:
        df_address[i] = df_address['address'].apply(lambda x: x[i] if x[i]!='' else 'Not Specified')

df_address.drop(columns=['address'], inplace=True)
df_address.head()
# Out:
#         _id                       street         suburb  \
# 0  10006546       Porto, Porto, Portugal  Not Specified
# 1  10047964    Kadıköy, İstanbul, Turkey           Moda
# 2  10057447     Montréal, Québec, Canada       Mile End
# 3  10083468       Porto, Porto, Portugal  Not Specified
# 4  10096773  New York, NY, United States      Manhattan
#
#                                      government_area    market        country  \
# 0  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...     Porto       Portugal
# 1                                            Kadikoy  Istanbul         Turkey
# 2                              Le Plateau-Mont-Royal  Montreal         Canada
# 3  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...     Porto       Portugal
# 4                                            Chelsea  New York  United States
#
#   country_code location_type  longitude  latitude  is_location_exact
# 0           PT         Point   -8.61308  41.14130              False
# 1           TR         Point   29.03133  40.98585               True
# 2           CA         Point  -73.59111  45.51889               True
# 3           PT         Point   -8.61123  41.15225              False
# 4           US         Point  -74.00074  40.74577               True

# %%
df_address['is_location_exact'] = df_address['is_location_exact'].map({False:'No',True:'Yes'})
df_address.head()
# Out:
#         _id                       street         suburb  \
# 0  10006546       Porto, Porto, Portugal  Not Specified
# 1  10047964    Kadıköy, İstanbul, Turkey           Moda
# 2  10057447     Montréal, Québec, Canada       Mile End
# 3  10083468       Porto, Porto, Portugal  Not Specified
# 4  10096773  New York, NY, United States      Manhattan
#
#                                      government_area    market        country  \
# 0  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...     Porto       Portugal
# 1                                            Kadikoy  Istanbul         Turkey
# 2                              Le Plateau-Mont-Royal  Montreal         Canada
# 3  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...     Porto       Portugal
# 4                                            Chelsea  New York  United States
#
#   country_code location_type  longitude  latitude is_location_exact
# 0           PT         Point   -8.61308  41.14130                No
# 1           TR         Point   29.03133  40.98585               Yes
# 2           CA         Point  -73.59111  45.51889               Yes
# 3           PT         Point   -8.61123  41.15225                No
# 4           US         Point  -74.00074  40.74577               Yes

# %%
df_address.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
df_address.dtypes
# Out:
# _id                   object
# street                object
# suburb                object
# government_area       object
# market                object
# country               object
# country_code          object
# location_type         object
# longitude            float64
# latitude             float64
# is_location_exact     object
# dtype: object

# %%
availability = []
for i in col.find( {}, {'_id':1, 'availability':1}):
    availability.append(i)

df_availability = pd.DataFrame(availability)
availability_keys = list(df_availability.iloc[0,1].keys())

for i in availability_keys:
    df_availability['availability_30'] = df_availability['availability'].apply(lambda x: x['availability_30'])
    df_availability['availability_60'] = df_availability['availability'].apply(lambda x: x['availability_60'])
    df_availability['availability_90'] = df_availability['availability'].apply(lambda x: x['availability_90'])
    df_availability['availability_365'] = df_availability['availability'].apply(lambda x: x['availability_365'])

df_availability.drop(columns=['availability'], inplace=True)
df_availability.head()
# Out:
#         _id  availability_30  availability_60  availability_90  \
# 0  10006546               28               47               74
# 1  10047964               27               57               87
# 2  10057447                0                0                0
# 3  10083468               16               40               67
# 4  10096773                0                0                0
#
#    availability_365
# 0               239
# 1               362
# 2                 0
# 3               335
# 4                 0

# %%
df_availability.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df_availability.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %%
pd.set_option('display.max_columns',None)

# %%
def amenities_sort(x):
    a = x
    a.sort(reverse=False)
    return a

amenities = []
for i in col.find( {}, {'_id':1, 'amenities':1}):
    amenities.append(i)

df_amenities = pd.DataFrame(amenities)
df_amenities['amenities'] = df_amenities['amenities'].apply(lambda x: amenities_sort(x))
df_amenities.head()
# Out:
#         _id                                          amenities
# 0  10006546  [Bed linens, Buzzer/wireless intercom, Cable T...
# 1  10047964  [24-hour check-in, Cable TV, Cat(s), Essential...
# 2  10057447  [24-hour check-in, Dryer, Essentials, Family/k...
# 3  10083468  [Accessible-height bed, Bed linens, Cable TV, ...
# 4  10096773  [Carbon monoxide detector, Essentials, Fire ex...

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
df_amenities.dtypes
# Out:
# _id          object
# amenities    object
# dtype: object

# %%
df = pd.merge(df_1, df_host, on='_id')
df = pd.merge(df, df_address, on='_id')
df = pd.merge(df, df_availability, on='_id')
df = pd.merge(df, df_amenities, on='_id')

df.head()
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10047964  https://www.airbnb.com/rooms/10047964
# 2  10057447  https://www.airbnb.com/rooms/10057447
# 3  10083468  https://www.airbnb.com/rooms/10083468
# 4  10096773  https://www.airbnb.com/rooms/10096773
#
#                              name property_type        room_type  bed_type  \
# 0         Ribeira Charming Duplex         House  Entire home/apt  Real Bed
# 1  Charming Flat in Downtown Moda         House  Entire home/apt  Real Bed
# 2  Modern Spacious 1 Bedroom Loft     Apartment  Entire home/apt  Real Bed
# 3               Be Happy in Porto          Loft  Entire home/apt  Real Bed
# 4       Easy 1 Bedroom in Chelsea     Apartment  Entire home/apt  Real Bed
#
#    minimum_nights  maximum_nights cancellation_policy  accommodates  bedrooms  \
# 0               2              30            moderate             8         3
# 1               2            1125            flexible             6         2
# 2               1            1125            flexible             4         1
# 3               2            1125            moderate             2         1
# 4               2            1125            flexible             2         1
#
#    beds  number_of_reviews  bathrooms  price   cleaning_fee  extra_people  \
# 0     5                 51        1.0     80             35            15
# 1     6                  1        1.0    527            211           211
# 2     2                  0        1.0     50  Not Specified            31
# 3     1                178        1.0     30             10             0
# 4     1                  1        1.0    145             60             0
#
#    guests_included                                             images  \
# 0                6  https://a0.muscache.com/im/pictures/e83e702f-e...
# 1                1  https://a0.muscache.com/im/pictures/231120b6-e...
# 2                1  https://a0.muscache.com/im/pictures/9fa69ad8-c...
# 3                1  https://a0.muscache.com/im/pictures/9420dabf-6...
# 4                1  https://a0.muscache.com/im/pictures/ceb6e8b2-d...
#
#    review_scores   host_id                                    host_url  \
# 0             89  51399391  https://www.airbnb.com/users/show/51399391
# 1            100   1241644   https://www.airbnb.com/users/show/1241644
# 2              0  51612949  https://www.airbnb.com/users/show/51612949
# 3             97  27518920  https://www.airbnb.com/users/show/27518920
# 4            100  34607505  https://www.airbnb.com/users/show/34607505
#
#      host_name                          host_location host_response_time  \
# 0  Ana&Gonçalo        Porto, Porto District, Portugal     within an hour
# 1       Zeynep             Istanbul, Istanbul, Turkey      Not Specified
# 2   Konstantin               Montreal, Quebec, Canada      Not Specified
# 3        Fábio  São Félix da Marinha, Porto, Portugal     within an hour
# 4        Scott      New York, New York, United States      Not Specified
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...
# 1  https://a0.muscache.com/im/users/1241644/profi...
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 3  https://a0.muscache.com/im/pictures/user/30283...
# 4  https://a0.muscache.com/im/pictures/675cec89-7...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
# 1  https://a0.muscache.com/im/users/1241644/profi...               Moda
# 2  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 3  https://a0.muscache.com/im/pictures/user/30283...      Not Specified
# 4  https://a0.muscache.com/im/pictures/675cec89-7...            Chelsea
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                100                No                  Yes
# 1      Not Specified                No                  Yes
# 2      Not Specified                No                  Yes
# 3                 90               Yes                  Yes
# 4      Not Specified                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    Yes                    3                          3
# 1                    Yes                    2                          2
# 2                     No                    1                          1
# 3                    Yes                    3                          3
# 4                    Yes                    1                          1
#
#                                   host_verifications  \
# 0  [email, phone, reviews, jumio, offline_governm...
# 1  [email, phone, facebook, reviews, jumio, gover...
# 2  [email, phone, jumio, offline_government_id, s...
# 3  [email, phone, reviews, manual_offline, jumio,...
# 4             [email, phone, facebook, reviews, kba]
#
#                         street         suburb  \
# 0       Porto, Porto, Portugal  Not Specified
# 1    Kadıköy, İstanbul, Turkey           Moda
# 2     Montréal, Québec, Canada       Mile End
# 3       Porto, Porto, Portugal  Not Specified
# 4  New York, NY, United States      Manhattan
#
#                                      government_area    market        country  \
# 0  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...     Porto       Portugal
# 1                                            Kadikoy  Istanbul         Turkey
# 2                              Le Plateau-Mont-Royal  Montreal         Canada
# 3  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...     Porto       Portugal
# 4                                            Chelsea  New York  United States
#
#   country_code location_type  longitude  latitude is_location_exact  \
# 0           PT         Point   -8.61308  41.14130                No
# 1           TR         Point   29.03133  40.98585               Yes
# 2           CA         Point  -73.59111  45.51889               Yes
# 3           PT         Point   -8.61123  41.15225                No
# 4           US         Point  -74.00074  40.74577               Yes
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0               28               47               74               239
# 1               27               57               87               362
# 2                0                0                0                 0
# 3               16               40               67               335
# 4                0                0                0                 0
#
#                                            amenities
# 0  [Bed linens, Buzzer/wireless intercom, Cable T...
# 1  [24-hour check-in, Cable TV, Cat(s), Essential...
# 2  [24-hour check-in, Dryer, Essentials, Family/k...
# 3  [Accessible-height bed, Bed linens, Cable TV, ...
# 4  [Carbon monoxide detector, Essentials, Fire ex...

# %%
df.to_csv('airbnb.csv', index=False)
